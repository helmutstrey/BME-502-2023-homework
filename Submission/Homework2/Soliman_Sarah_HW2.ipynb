# %% [markdown]
# <h1>HW2</h1>

# %% [markdown]
# #### Bayes' theorem:
# \begin{equation*}
# P(A|B) = \frac{P(B|A)P(A)}{P(B)} \\
# P(A|B): Posteior \\
# P(B|A): Likelihood \\
# P(A): Prior \\
# P(B): Marginal Probability \\
# \end{equation*}

# %% [markdown]
# # Question 1
# ### Read the following example and complete the exercises
#
# You are at the age of 21 and curious about if drinking alcohol would cause liver disease. You contacted a clinic site and got the following information.
#
# 1. Past data tells you that 10% of patients entering the clinic have liver disease (**Prior**).
#
# 2. Five percent of the clinic’s patients are alcoholics (**Marginal Probability**).
#
# 3. Among the patients diagnosed with liver disease, 15% are alcoholics (**Likelihood**).
#
# Now you wonder what is the probability of a patient from the clinic have liver disease given that the patient is alcoholic (**Posterior**)

# %% [markdown]
# ### 1.1
#
# #### If A represents the event of being an alcoholic patient in the clinic and L represents the event of being a patient with liver disease in the clinic, write the bayesian representation (P(A|B)) in the following cells

# %% [markdown]
# Posteria = P(L|A) probability of Liver disease given Alcoholism

# %% [markdown]
# Prior = P(L) probability of Liver Disease

# %% [markdown]
# Likelihood = P(A|L) probability of Alcoholism given Liver Disease

# %% [markdown]
# Marginal Probability = P(A) probability of Alcoholism

# %% [markdown]
# ### 1.2
#
# #### Define all the information available and calculate the posteria probbability

# %%
LD = 0.1; #probability of liver disease
A = 0.05; #prob of alcoholism
A_LD = 0.15; #prob of alcoholism given liver disease

LD_A = A_LD * LD / A
println("The probability that a patient has liver disease given that the patient is an alcoholic is ",(LD_A*100),"%!")
# Out:
# The probability that a patient has liver disease given that the patient is an alcoholic is 30.0%!

# %% [markdown]
# # Question 2
# ### Read the following example and complete the exercises
# Shown by a <a href="https://pubmed.ncbi.nlm.nih.gov/34242764/#:~:text=The%20overall%20sensitivity%20of%20the,%25%20CI%2024.4%2D65.1">reaserch study</a>, the rapid antigen test for Covid has a sensitivity of 65.3% and a specificity of 99.9%. Assume 1% people have Covid. If randomly select a person and he/she tests positive using the rapid antigen test, what is the probability the person has Covid (posterior).

# %% [markdown]
# ### 2.1
#
# #### The probability of which event is considered marginal probability in this case? Define it in the first cell below and calculate it in the second cell below

# %% [markdown]
# The event is:

# %%
#cov = has covid ; pos = tests positive ; neg = tests negative ; nocov = doesn't have covid
#posteria = P(cov|pos)
pcov_pos = ()
#prior = P(cov) 
pcov = 0.01
pnocov = 1 - pcov
#likelihood = P(pos|covid) = sensitivity
ppos_cov = 0.653
#marginal = P(pos)
ppos = ()

#specificity = P(neg|nocov)
pneg_nocov = 0.999
ppos_nocov = 1 - pneg_nocov

# %% [markdown]
# ### 2.2
#
# #### Define all the information and calculate the probability the randomly selected person has Covid

# %%
#ppos equals the sum of P(pos AND cov) and P(pos AND nocov)
ppos = (pcov*ppos_cov) + (pnocov*ppos_nocov)

pcov_pos = pcov*ppos_cov/ppos
# Out:
# 0.8683510638297872

# %%
println("The probability that someone has covid given a positive test is ", Float16(pcov_pos*100), "%!")
# Out:
# The probability that someone has covid given a positive test is 86.8%!

# %% [markdown]
# # Question 3
# ### <a href="https://juliastats.org/Distributions.jl/stable/starting/">This page</a> is the documentation for Distribution.jl and complete the exercies

# %% [markdown]
# ### 3.1
#
# #### Randomly draw 1000 samples from a normal distribution with mean = 5 and std = 2

# %%
import Pkg
Pkg.add("Random")
Pkg.add("Distributions")
Pkg.add("Plots")
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\solim\.julia\environments\v1.8\Project.toml`
#   No Changes to `C:\Users\solim\.julia\environments\v1.8\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\solim\.julia\environments\v1.8\Project.toml`
#   No Changes to `C:\Users\solim\.julia\environments\v1.8\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\solim\.julia\environments\v1.8\Project.toml`
#   No Changes to `C:\Users\solim\.julia\environments\v1.8\Manifest.toml`
# UndefVarError: Random not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[10]:6

# %%
using Random, Distributions
Random.seed!(123)
d = Normal(5,2)
# Out:
# Normal{Float64}(μ=5.0, σ=2.0)

# %%
x = rand(d, 1000)
# Out:
# 1000-element Vector{Float64}:
#  3.7085386557920463
#  2.073497242222157
#  1.7527925088278389
#  4.5646697864329076
#  5.984491373050366
#  6.961959624248298
#  5.15991365901012
#  8.098249106085584
#  2.3167815182335563
#  5.8243232693659355
#  6.1863947762419516
#  3.463182162537386
#  4.847664109095126
#  ⋮
#  6.247790665546262
#  5.438084785027371
#  5.299552975722957
#  6.602236558637884
#  5.804729417569904
#  5.178755748468589
#  5.812327059101699
#  7.568639904523696
#  4.819505796383868
#  4.8872935799702955
#  4.945875161371136
#  4.655382388653741

# %% [markdown]
# ### 3.2
#
# #### Plot  the distribution above in a histogram

# %%
using Plots
histogram(x)

# %% [markdown]
# ### 3.3
#
# #### Plot  the same distribution and change the bins to 50

# %%
histogram(x, bins = 50)

# %% [markdown]
# ### 3.4
#
# #### Choose a distribution other than normal distribution, Describe what it represents, and draw 1000 samples from the distribution and plot it using parameters of your choice

# %% [markdown]
# Which distribution do you pick:

# %% [markdown]
# What does the distribution represent?

# %%
#Choosing Binomial distribution which is denoted by the parameters n and p, where n is a fixed number of independent
# Bernoulli trials (such as flipping a coin), p is the probability of success in each trial
bi_d = Binomial(15, 0.75) # out of 500 trials, and 75% chance of success in each trial
a = rand(bi_d,1000)
# Out:
# 1000-element Vector{Int64}:
#  12
#  10
#  13
#  13
#   8
#   9
#  11
#  11
#  11
#   7
#  12
#  14
#  13
#   ⋮
#  14
#  11
#  13
#  11
#  11
#  10
#  10
#  10
#  11
#  14
#  11
#  14

# %% [markdown]
# ### 3.5
#
# #### Plot  the two distributions in the same plot

# %%
histogram!(a, bins = 50)

# %% [markdown]
# ### 3.6
#
# #### Draw 10000 samples from the two distributions separately and plot them in the same plot

# %%
b = rand(d,10000)
c = rand(bi_d,10000)
histogram(b, bins = 100)
histogram!(c, bins = 100)

# %% [markdown]
# # Question 4
# ### Read the following example and complete the exercises
# Bayes is playing Russian roulette. The revolver has six chambers. He puts two bullets in two adjacent chambers, spin the cylinder, hold the gun to his head, and pull the trigger. It clicks. So it is now the second try: he can choose either to spin the cylinder again or leave it as it is.

# %% [markdown]
# ### 4.1
#
# #### What is the probability that Bayes survives the second try given his survival in the first try if he spin the cylinder and explain

# %% [markdown]
# If Bayes survives the first try and decides to spin the cyclinder again, he will recreate the same starting condition of 2/6 slots being deadly. This means that spinning the cyclinder again would give a probability of 1/3 getting shot. So the probabilty of survival would be 2/3.
#
# 1st round:
# chance of survival = 4/6 = 2/3
#
# 2nd round AFTER a respin:
# chance of survival = 4/6 = 2/3
# The chance of survival does not change after a respin because the amount of bullets and blanks in the chamber does not change.

# %% [markdown]
# ### 4.2
# #### In this case, what are the relation between P(A|B), P(B), and P(A) if A represents survival in the first try and B represents survival in the second try

# %% [markdown]
# P(A) = 4/6 = 2/3
# Respinning after A resets the conditions back to 2 adjacent bullets and 4 blanks with no new knowledge of positioning, so:
# P(B|A) = P(A) = P(B) = 2/3

# %% [markdown]
# ### 4.3
#
# #### What is the probability that Bayes survives both tries without spinning the cylinder and explain

# %% [markdown]
# 1st round: P(survival) = 2/3
# if Bayes has already survived the first round that means the chamber was in 1 of four possible positions
# no respin means there is a 1/4 chance that the blank fired in the first round was the last one and the next is a bullet so
# 2nd round: P(survival|1st round) = 3/4

# %% [markdown]
# ### 4.4
#
# #### Use answers from 4.1 and 4.3 to calculate the probability that Bayes survives the second try given his survial in the first try if he doesn't spin the cylinder and explain

# %%
#Key: 0 = blank, 1 = bullet
#1st round:
p_0 = 2/3 #prob of a blank
p_1 = 1/3 #prob of a bullet
#2nd round:
p_0_1 = 1/2; #prob of a blank given a bullet is 1/2 because the next shot is either a blank or a bullet since the bullets are adjacent 
p_1_0 = (); #prob of a bullet given a blank, we want to find this

#using Baye's theorem:
p_1_0 = p_1*p_0_1/p_0
# Out:
# 0.25

# %%
#If there is a 25% chance of a bullet given a blank, then no respin gives:
Bayes_survival_norespin = 1-p_1_0
# Out:
# 0.75
