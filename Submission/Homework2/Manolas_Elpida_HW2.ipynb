# %% [markdown]
# <h1>HW2</h1>

# %% [markdown]
# #### Bayes' theorem:
# \begin{equation*}
# P(A|B) = \frac{P(B|A)P(A)}{P(B)} \\
# P(A|B): Posteior \\
# P(B|A): Likelihood \\
# P(A): Prior \\
# P(B): Marginal Probability \\
# \end{equation*}

# %% [markdown]
# # Question 1
# ### Read the following example and complete the exercises
#
# You are at the age of 21 and curious about if drinking alcohol would cause liver disease. You contacted a clinic site and got the following information.
#
# 1. Past data tells you that 10% of patients entering the clinic have liver disease (**Prior**).
#
# 2. Five percent of the clinic’s patients are alcoholics (**Marginal Probability**).
#
# 3. Among the patients diagnosed with liver disease, 15% are alcoholics (**Likelihood**).
#
# Now you wonder what is the probability of a patient from the clinic have liver disease given that the patient is alcoholic (**Posterior**)

# %% [markdown]
# ### 1.1
#
# #### If A represents the event of being an alcoholic patient in the clinic and L represents the event of being a patient with liver disease in the clinic, write the bayesian representation (P(A|B)) in the following cells

# %% [markdown]
# Posteria = P(L|A) = ?

# %% [markdown]
# Prior = P(L) = 10%

# %% [markdown]
# Likelihood = P(A|L) = 15%

# %% [markdown]
# Marginal Probability = P(A) = 5%

# %% [markdown]
# ### 1.2
#
# #### Define all the information available and calculate the posteria probbability

# %%
PR = .10
MP = .05
LI = .15
#PO = ?

#P(A|B) = (P(A&B)/P(B))
#P(L|A) = (P(L&A)/P(A))
#P(A&B) = (P(B|A)*P(A))
#P(L|A) = (P(A|L)*P(L))/P(A)

#𝑃(L|A)=𝑃(A|L)𝑃(L)/𝑃(A)

PO = (LI*PR)/MP
# Out:
# 0.3

# %% [markdown]
# # Question 2
# ### Read the following example and complete the exercises
# Shown by a <a href="https://pubmed.ncbi.nlm.nih.gov/34242764/#:~:text=The%20overall%20sensitivity%20of%20the,%25%20CI%2024.4%2D65.1">reaserch study</a>, the rapid antigen test for Covid has a sensitivity of 65.3% and a specificity of 99.9%. Assume 1% people have Covid. If randomly select a person and he/she tests positive using the rapid antigen test, what is the probability the person has Covid (posterior).

# %% [markdown]
# ### 2.1
#
# #### The probability of which event is considered marginal probability in this case? Define it in the first cell below and calculate it in the second cell below

# %% [markdown]
# The event is: Receiving a positive test

# %%
#POS = P(POS|Covid)*P(Covid)+P(POS|NCovid)*P(NCovid)
POS = 0.653*0.01+0.001*0.99
# Out:
# 0.007520000000000001

# %% [markdown]
# ### 2.2
#
# #### Define all the information and calculate the probability the randomly selected person has Covid

# %%
#P(P|C) Probability of positive test given covid = 0.653
#P(P|NC) Probability of positive test given no covid = 0.001

PC = 0.01 #Possibility of COVID #prior
PNC = 0.99 #Possibility of not COVID
PGC = 0.653 #Possibility of POS given COVID
PGNC = 0.001 #Possibility of POS given NO COVID (because sensitivity is 99.9%) 

POS = PGC*PC+PGNC*PNC

#Covid Given Positive Test
CGP = (PGC*PC)/POS
# Out:
# 0.8683510638297872

# %% [markdown]
# # Question 3
# ### <a href="https://juliastats.org/Distributions.jl/stable/starting/">This page</a> is the documentation for Distribution.jl and complete the exercies

# %% [markdown]
# ### 3.1
#
# #### Randomly draw 1000 samples from a normal distribution with mean = 5 and std = 2

# %%
using Random, Distributions, Plots

# %%
n1 = Normal(5,2)
normal_sample = rand(n1, 1000)
# Out:
# 1000-element Vector{Float64}:
#   4.871781277056043
#   5.38242569355649
#   4.154456137160739
#   4.51441676720322
#   7.501539504329211
#   0.8393240495011591
#   7.0076718820770845
#   5.657897222053627
#  10.624490211805583
#   6.9233746058380765
#   5.411058183856216
#   1.1548541434357085
#   4.143592208099542
#   ⋮
#   3.690894675036628
#   6.415308878164596
#   2.1146936854833758
#   6.333542960706936
#   1.6454374751260201
#   3.8527724734171005
#   2.70496233326735
#   2.990306132836549
#   5.06285364071952
#   7.167907527246163
#   7.5338902362734395
#   4.267537016440222

# %% [markdown]
# ### 3.2
#
# #### Plot  the distribution above in a histogram

# %%
histogram(normal_sample, normalize = true)

# %% [markdown]
# ### 3.3
#
# #### Plot  the same distribution and change the bins to 50

# %%
histogram(normal_sample, bins=50, normalize = true)

# %% [markdown]
# ### 3.4
#
# #### Choose a distribution other than normal distribution, Describe what it represents, and draw 1000 samples from the distribution and plot it using parameters of your choice

# %% [markdown]
# Which distribution do you pick: Binomial

# %% [markdown]
# What does the distribution represent?: It represents the success over a number of trials (n) with the probability of success for a single trial (p) being equal across them all.

# %%
b1 = Binomial(10,0.5)
binomial_sample = rand(b1, 1000)
# Out:
# 1000-element Vector{Int64}:
#  5
#  5
#  5
#  6
#  6
#  2
#  6
#  4
#  4
#  3
#  8
#  8
#  5
#  ⋮
#  4
#  5
#  4
#  6
#  6
#  5
#  7
#  7
#  7
#  6
#  4
#  6

# %% [markdown]
# ### 3.5
#
# #### Plot  the two distributions in the same plot

# %%
histogram(normal_sample)
histogram!(binomial_sample)

# %% [markdown]
# ### 3.6
#
# #### Draw 10000 samples from the two distributions separately and plot them in the same plot

# %%
normal_sample = rand(n1, 10000)
binomial_sample = rand(b1, 10000)
histogram(normal_sample)
histogram!(binomial_sample)

# %% [markdown]
# # Question 4
# ### Read the following example and complete the exercises
# Bayes is playing Russian roulette. The revolver has six chambers. He puts two bullets in two adjacent chambers, spin the cylinder, hold the gun to his head, and pull the trigger. It clicks. So it is now the second try: he can choose either to spin the cylinder again or leave it as it is.

# %% [markdown]
# ### 4.1
#
# #### What is the probability that Bayes survives the second try given his survival in the first try if he spin the cylinder and explain

# %% [markdown]
# If he spins the cylinder then he once again has a 2/3 chance of survical. Since the first shot did not have a bullet, there are still 2 bullets in the chamber out of 6 possible shots, therefore a 1/3 chance of getting shot. If the chamber is re-spun, the probability resets and there is no information to apply that would chance any other possibilities, there are 4 empty chambers out of 6 still, making it a 2/3 survival chance.

# %% [markdown]
# ### 4.2
# #### In this case, what are the relation between P(B|A), P(B), and P(A) if A represents survival in the first try and B represents survival in the second try

# %% [markdown]
# P(A) = survival in the first try = 4/6
# Re-Spin
# P(B) = survival in the second try = 4/6
#
# P(B|A) = P(A) = 4/6 = 2/3

# %% [markdown]
# ### 4.3
#
# #### What is the probability that Bayes survives both tries without spinning the cylinder and explain

# %% [markdown]
# P(AandB) = P(A)*P(B)
#
# For this case, the probability of surviving both try A and try B, would have to be 2/3 * 3/4, which is 1/2
#
# Therefore, the probability of surviving both tries without spinning the cylinder again is 1/2.

# %% [markdown]
# ### 4.4
#
# #### Use answers from 4.1 and 4.3 to calculate the probability that Bayes survives the second try given his survial in the first try if he doesn't spin the cylinder and explain

# %%
#Probability of survival in the second try, given survival in the first (without a re-spin)

#P(A) = survival of 1st round = 2/3
PA = 2/3
#P(B) = survival of 2nd round = 3/4
PB = 3/4
#P(AandB) = survival of 1st and 2nd round
PAB = 1/2

#P(B|A) = P(A and B)/P(A)
PBGA = (PA*PB)/PA
# Out:
# 0.75

# %% [markdown]
# If Bayes were to not spin the chamber, he would have a 3/4 chance of survival, given he survives the first shot. If the first shot is a blank, that means there are 2 spots in the chamber in which it would be impossible for the gun to have fired from. This provides us with 4 possible chambers that the gun could have shot from, but only one of them is directly adjacent to a chamber containing a bullet in line. This means that out of the 4 possible chambers (no longer 6 because we have gained information from the first shot being blank), only one shot has a bullet in it. Therefore there is a 25% chance the next shot will be fatal, and a 75% chance of survival.
