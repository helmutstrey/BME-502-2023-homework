# %%
Prior = 0.1
Marginal_Probability = .05
Likelihood = .15
Posterior = (Likelihood*Prior)/Marginal_Probability
# Out:
# 0.3

# %%
# P(A) = 0.1, P(L) = .05, P(L/A) = .15
# P(A/L) = P(L/A) * P(A)/P(L)
Prior = 0.1
Marginal_Probability = .05
Likelihood = .15
Posterior = (Likelihood*Prior)/Marginal_Probability
# Out:
# 0.3

# %%
# The event is people testing positive for Covid with Covid

# %%
pos_given_covid = .653
covid = .01
pos_given_neg_covid= .001
true_neg = .99
pos_test = ((pos_given_covid * covid) + (pos_given_neg_covid * true_neg))
# Out:
# 0.007520000000000001

# %%
# pos_test = ((pos_given_covid * covid) + (pos_given_neg_covid * true_neg)) = 0.007520000000000001
# P(pos_test/covid)=0.653
# P(covid)=0.01
# pos_given_covid = P(pos_test/covid)*P(covid)/P(pos_test)
covid_given_pos_test=(pos_given_covid * covid) / pos_test
# Out:
# 0.8683510638297872

# %%
import Pkg
Pkg.add("Random")
Pkg.add("Distributions")
Pkg.add("Plots")
using Random, Distributions, Plots, Statistics
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`

# %%
n1 = Normal(5,2)
normal_sample = rand(n1,1000)
# Out:
# 1000-element Vector{Float64}:
#  7.72147060032955
#  2.422993424527835
#  5.385700362154657
#  4.623265683067849
#  5.381271234134189
#  7.131457456603627
#  5.49382005067109
#  2.285998699870244
#  4.92082525170022
#  2.585187421769876
#  4.66350507374767
#  4.752230088114386
#  5.470238601911886
#  ⋮
#  4.312437708009184
#  8.873679704763706
#  3.111143807740145
#  4.8485722417690935
#  6.651889262867257
#  6.3442090421812285
#  5.18461050589917
#  7.681705471898509
#  6.121015942377319
#  4.394055037004505
#  8.042984681130687
#  6.933939286683422

# %%
histogram(normal_sample)

# %%
histogram(normal_sample, bins=50)

# %%
n2 = Cauchy(5,2)
normal_sample2 = rand(n2, 1000)
histogram(normal_sample2, bins=50)

# %%
#Cauchy distribution
#Ratio of 2 independent normally disturbed random variables if the denominator has mean 0

# %%
histogram(normal_sample, bins=50)
histogram!(normal_sample2, bins=50)

# %%
n1 = Normal(5,2)
normal_sample = rand(n1,1000)
histogram(normal_sample, bins=50, normalize=true)

# %%
n2 = Cauchy(5,2)
normal_sample2 = rand(n2, 1000)
histogram(normal_sample2, bins=50, normalize=true)

# %%
histogram(normal_sample, bins=50, normalize=true)
histogram!(normal_sample2, bins=50, normalize=true)

# %%
#If Bayes spins the cylinder before shooting again there is a 4/6 chance that you remain safe becuase there are still 4 out of 6 empty chambers.

# %%
#Both P(B) and P(A) are independent of each other so P(B/A) = P(B) and P(B) = P(A)

# %%
# The probability that Bayes survives both tries without spinning is 2/4 becuase there are two chambers that can kill u assuming youre starting on an empty chamber.

# %%
#P(A)=survives second try = 3/4
#P(B)=survives first try = 4/6
#P(B/A) = 4/6
#P(A/B)= (P(A)*P(B)) / P(B)
# 3/4
